# %%
# Drew Pickett Data Structures

from binary_search_tree import BinarySearchTree, Node
from patient_record_mgmt import PatientRecordManagementSystem

bst = PatientRecordManagementSystem()

file_path = "C:\\Users\\drewp\\OneDrive\\Documents\\project3\\data\\patient_records.csv"
bst.build_tree_from_csv(file_path)

print("inital:")
bst.display_all_records()
print("")
print("search for 2: ", bst.search_patient_record(2))
print("search for 25", bst.search_patient_record(25))
print("search for 47", bst.search_patient_record(47))
print("")
bst.delete_patient_record(3)
bst.delete_patient_record(10)
bst.delete_patient_record(30)
print("after-deletion:")
bst.display_all_records()
print("")
bst.add_patient_record(51, "Jacob Marley", 40, "Migraine", "120/80", 70, 37.0)
bst.add_patient_record(58, "Robert Shea", 55, "Back Pain", "130/85", 75, 36.8)
bst.add_patient_record(3, "Joan Smith", 33, "Anxiety", "115/75", 68, 37.1)
print("after-insertion:")
bst.display_all_records()
# Out:
# inital:
# Patient Records:
# ID: 1, Name: Peter Parker, Age: 35, Diagnosis: Flu, BP: 120/80, Pulse: 70, Temp: 37.0
# ID: 3, Name: Clint Barton, Age: 45, Diagnosis: Hypertension, BP: 140/90, Pulse: 80, Temp: 36.9
# ID: 5, Name: Tony Stark, Age: 60, Diagnosis: Arthritis, BP: 125/78, Pulse: 72, Temp: 36.7
# ID: 6, Name: Natasha Romanoff, Age: 32, Diagnosis: Cold, BP: 115/75, Pulse: 68, Temp: 37.1
# ID: 7, Name: Scott Lang, Age: 47, Diagnosis: Cancer, BP: 135/88, Pulse: 77, Temp: 37.0
# ID: 8, Name: Drax, Age: 55, Diagnosis: Heart Disease, BP: 145/92, Pulse: 82, Temp: 36.8
# ID: 9, Name: Wade Wilson, Age: 40, Diagnosis: Flu, BP: 120/80, Pulse: 70, Temp: 36.9
# ID: 10, Name: Professor X, Age: 29, Diagnosis: Pneumonia, BP: 130/85, Pulse: 75, Temp: 37.3
# ID: 11, Name: James Rhodes, Age: 65, Diagnosis: Diabetes, BP: 140/90, Pulse: 80, Temp: 37.0
# ID: 12, Name: Carol Danvers, Age: 38, Diagnosis: Hypertension, BP: 110/70, Pulse: 65, Temp: 36.9
# ...
