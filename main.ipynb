# %%
from binary_search_tree import BinarySearchTree, Node
from patient_record_mgmt import PatientRecordManagementSystem

bst = PatientRecordManagementSystem()

bst.add_patient_record(50, "John Doe", 44, "Flu", "120/80", "75", "98.6")
bst.add_patient_record(30, "Sarah Lee", 29, "Diabetes", "132/85", "80", "98.9")
bst.add_patient_record(70, "Mark Chan", 60, "Hypertension", "150/90", "90", "99.1")
bst.add_patient_record(25, "Emily Clark", 22, "Cold", "118/76", "70", "98.4")
bst.add_patient_record(65, "James Smith", 55, "Asthma", "110/70", "72", "98.5")

bst.display_all_records()
bst.delete_patient_record(25)
print("Removed Emily Clark")
print("Search for Emily Clark: ", bst.search_patient_record(25))
bst.display_all_records()
print("Search for John Doe: ", bst.search_patient_record(50))
# Out:
# Patient Records:
# ID: 25, Name: Emily Clark, Age: 22, Diagnosis: Cold, BP: 118/76, Pulse: 70, Temp: 98.4
# ID: 30, Name: Sarah Lee, Age: 29, Diagnosis: Diabetes, BP: 132/85, Pulse: 80, Temp: 98.9
# ID: 50, Name: John Doe, Age: 44, Diagnosis: Flu, BP: 120/80, Pulse: 75, Temp: 98.6
# ID: 65, Name: James Smith, Age: 55, Diagnosis: Asthma, BP: 110/70, Pulse: 72, Temp: 98.5
# ID: 70, Name: Mark Chan, Age: 60, Diagnosis: Hypertension, BP: 150/90, Pulse: 90, Temp: 99.1
# Removed Emily Clark
# Search for Emily Clark:  None
# Patient Records:
# ID: 30, Name: Sarah Lee, Age: 29, Diagnosis: Diabetes, BP: 132/85, Pulse: 80, Temp: 98.9
# ID: 50, Name: John Doe, Age: 44, Diagnosis: Flu, BP: 120/80, Pulse: 75, Temp: 98.6
# ID: 65, Name: James Smith, Age: 55, Diagnosis: Asthma, BP: 110/70, Pulse: 72, Temp: 98.5
# ID: 70, Name: Mark Chan, Age: 60, Diagnosis: Hypertension, BP: 150/90, Pulse: 90, Temp: 99.1
# Search for John Doe:  <binary_search_tree.Node object at 0x0000028C99F23D90>
